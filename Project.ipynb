# %% [markdown]
# Group Project

# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd

# Increase the default max number of columns displayed

from google.colab.data_table import DataTable
DataTable.max_columns = 100


# Load Dataset

data_df = pd.read_csv('/content/drive/MyDrive/Clustering Data (3).csv')

print(f'The dataset has {data_df.shape[0]} rows and {data_df.shape[1]} columns')

data_df.head()
# Out:
# Mounted at /content/drive
# The dataset has 15144 rows and 90 columns
#                                                  uid PNRLocatorID   avg_amt  \
# 0  504554455244696420493F7C2067657420746869732072...       AADMLF  0.019524
# 1  46495853454E44696420493F7C20676574207468697320...       AAFBOM  0.081774
# 2  534355545444696420493F7C2067657420746869732072...       AAFILI  0.026650
# 3  534355545444696420493F7C2067657420746869732072...       AAFILI  0.026650
# 4  44554D4D414E4E44696420493F7C206765742074686973...       AAFRQI  0.000000
#
#    round_trip  group_size  group  days_pre_booked  BookingChannel_Other  \
# 0           0       0.000      0         0.029703                     0
# 1           1       0.000      0         0.039604                     0
# 2           0       0.125      1         0.069307                     0
# 3           0       0.125      1         0.069307                     0
# 4           1       0.000      0         0.035361                     0
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## **Data Pre Processing**

# %%
missing_values = data_df.isnull().sum()
print(missing_values)
# Out:
# uid                          0
# PNRLocatorID                 0
# avg_amt                      0
# round_trip                   0
# group_size                   0
#                             ..
# UflyMemberStatus_Standard    0
# seasonality_Q1               0
# seasonality_Q2               0
# seasonality_Q3               0
# seasonality_Q4               0
# Length: 90, dtype: int64

# %%
clustering_copy = data_df.copy()
clustering_copy.head()
# Out:
#                                                  uid PNRLocatorID   avg_amt  \
# 0  504554455244696420493F7C2067657420746869732072...       AADMLF  0.019524
# 1  46495853454E44696420493F7C20676574207468697320...       AAFBOM  0.081774
# 2  534355545444696420493F7C2067657420746869732072...       AAFILI  0.026650
# 3  534355545444696420493F7C2067657420746869732072...       AAFILI  0.026650
# 4  44554D4D414E4E44696420493F7C206765742074686973...       AAFRQI  0.000000
#
#    round_trip  group_size  group  days_pre_booked  BookingChannel_Other  \
# 0           0       0.000      0         0.029703                     0
# 1           1       0.000      0         0.039604                     0
# 2           0       0.125      1         0.069307                     0
# 3           0       0.125      1         0.069307                     0
# 4           1       0.000      0         0.035361                     0
#
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## **Clustering**

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

inertia = []
cluster_range = range(1, 21)

columns_to_drop = ['uid', 'PNRLocatorID']
clustering_data = clustering_copy.drop(columns=columns_to_drop)


for i in cluster_range:
        print(f'Iteration Number : {i}')

        kmeans = KMeans(n_clusters= i, random_state=10)
        kmeans.fit(clustering_data)
        inertia.append(kmeans.inertia_)


plt.figure(figsize=(10,6))
plt.plot(cluster_range, inertia, marker="o", linestyle = "--")
plt.title("Elbow Curve Method")
plt.xlabel("Number of Clusters")
plt.ylabel("Inertia")
plt.grid(True)
plt.show()
# Out:
# Iteration Number : 1
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# Iteration Number : 2
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# Iteration Number : 3
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# Iteration Number : 4
# ...

# %%
kmeans = KMeans(n_clusters=5, random_state=42)
kmeans.fit((clustering_data))


# For Analysis
data_df['Cluster'] = kmeans.labels_
data_df.head(15144)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
#                                                      uid PNRLocatorID  \
# 0      504554455244696420493F7C2067657420746869732072...       AADMLF
# 1      46495853454E44696420493F7C20676574207468697320...       AAFBOM
# 2      534355545444696420493F7C2067657420746869732072...       AAFILI
# 3      534355545444696420493F7C2067657420746869732072...       AAFILI
# 4      44554D4D414E4E44696420493F7C206765742074686973...       AAFRQI
# ...                                                  ...          ...
# 15139  4C45415244696420493F7C206765742074686973207269...       ZZTNZF
# 15140  4D55454C4C455244696420493F7C206765742074686973...       ZZWDMH
# 15141  4F4245524C4544696420493F7C20676574207468697320...       ZZXFGK
# ...

# %%
number_of_clusters = data_df['Cluster'].nunique()

for i in range(number_of_clusters):
  print(f"the size of the cluster {i} | {data_df[data_df['Cluster'] == i].shape[0]}") #Important to remember
# Out:
# the size of the cluster 0 | 3843
# the size of the cluster 1 | 2353
# the size of the cluster 2 | 4127
# the size of the cluster 3 | 2436
# the size of the cluster 4 | 2385

# %%
number_of_clusters = data_df['Cluster'].nunique()

for i in range(number_of_clusters):
  print(f"the size of the cluster {i} | {data_df[data_df['Cluster'] == i].shape[0]}") #Important to remember
# Out:
# the size of the cluster 0 | 3843
# the size of the cluster 1 | 2353
# the size of the cluster 2 | 4127
# the size of the cluster 3 | 2436
# the size of the cluster 4 | 2385

# %% [markdown]
# ### ***Loading the sample Data Transformed***

# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd

# Increase the default max number of columns displayed

from google.colab.data_table import DataTable
DataTable.max_columns = 100

customer_data = pd.read_csv('/content/sample_data_transformed (3).csv')

print(f'The dataset has {customer_data.shape[0]} rows and {customer_data.shape[1]} columns')

customer_data.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# The dataset has 26575 rows and 37 columns
# <ipython-input-11-90478cc190f9>:11: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   customer_data = pd.read_csv('/content/sample_data_transformed (3).csv')
#    Unnamed: 0 PNRLocatorID PaxName     TicketNum  CouponSeqNbr  \
# 0           1       AADMLF  PETEJO  3.377490e+12             1
# 1           2       AAFBOM  FIXSMO  3.372110e+12             2
# 2           3       AAFBOM  FIXSMO  3.372110e+12             1
# 3           4       AAFILI  SCUTKA  3.372110e+12             2
# 4           5       AAFILI  SCUTKA  3.372110e+12             1
#
#   ServiceStartCity ServiceEndCity PNRCreateDate ServiceStartDate  \
# 0              MSP            DFW       9/15/14          10/6/14
# 1              JFK            MSP       7/22/14          8/19/14
# ...

# %% [markdown]
# ## **Merging the sample data**

# %%
final_dataframe = customer_data.merge(data_df[['uid', 'Cluster']], on='uid', how='left')
final_dataframe.head()
# Out:
#    Unnamed: 0 PNRLocatorID PaxName     TicketNum  CouponSeqNbr  \
# 0           1       AADMLF  PETEJO  3.377490e+12             1
# 1           2       AAFBOM  FIXSMO  3.372110e+12             2
# 2           3       AAFBOM  FIXSMO  3.372110e+12             1
# 3           4       AAFILI  SCUTKA  3.372110e+12             2
# 4           5       AAFILI  SCUTKA  3.372110e+12             1
#
#   ServiceStartCity ServiceEndCity PNRCreateDate ServiceStartDate  \
# 0              MSP            DFW       9/15/14          10/6/14
# 1              JFK            MSP       7/22/14          8/19/14
# 2              MSP            JFK       7/22/14          8/14/14
# 3              MSP            SEA        2/6/14          3/27/14
# 4              LAN            MSP        2/6/14          3/27/14
#
#                                        EncryptedName  ... age_group  \
# 0  504554455244696420493F7C2067657420746869732072...  ...       55+
# ...

# %% [markdown]
# ### **Analysis and Visualization**

# %%
cluster_colors = {
    0 : 'red',
    1 : 'blue',
    2 : 'orange',
    3 : 'green',
    4 : 'darkgrey'
}

cluster_sizes = final_dataframe['Cluster'].value_counts().sort_index()


plt.figure(figsize=(10, 6))

for cluster in range(len(cluster_sizes)):
  plt.bar(cluster, cluster_sizes[cluster], color=cluster_colors[cluster])

plt.title('Cluster Sizes')
plt.xlabel('Cluster')
plt.ylabel('Number of People')
plt.xticks(ticks=range(len(cluster_sizes)))
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

cluster_colors = {
    0 : 'red',
    1 : 'blue',
    2 : 'orange',
    3 : 'green',
    4 : 'darkgrey'
}

cluster_sizes = final_dataframe['Cluster'].value_counts().sort_index()

plt.figure(figsize=(10, 6))

for cluster in range(len(cluster_sizes)):
    plt.bar(cluster, cluster_sizes[cluster], color=cluster_colors[cluster])
    plt.text(cluster, cluster_sizes[cluster] + 10,  # Adjust "+ 10" as needed for spacing
             str(cluster_sizes[cluster]), ha='center', va='bottom')

plt.title('Cluster Sizes')
plt.xlabel('Cluster')
plt.ylabel('Number of People')
plt.xticks(ticks=range(len(cluster_sizes)))
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Filter out rows where BaseFareAmt is 0
filtered_dataframe = final_dataframe[final_dataframe['BaseFareAmt'] != 0]

# Calculate the average Base Fare amount for each cluster
cluster_avgamt = filtered_dataframe.groupby('Cluster')['BaseFareAmt'].mean()

cluster_colors = {
    0: 'red',
    1: 'blue',
    2: 'orange',
    3: 'green',
    4: 'darkgrey'
}

plt.figure(figsize=(10, 6))

for cluster in range(len(cluster_avgamt)):
    plt.bar(cluster, cluster_avgamt[cluster], color=cluster_colors[cluster])
    # Add the average value as text on top of the bar
    plt.text(cluster, cluster_avgamt[cluster] + 10,  # Adjust "+ 10" for spacing
             f'{cluster_avgamt[cluster]:.2f}', ha='center', va='bottom', fontsize=10, color='black')

plt.title('Base Fare Average Amounts Spent Per Cluster')
plt.xlabel('Cluster')
plt.ylabel('Average Base Fare Amount Spent')
plt.xticks(ticks=range(len(cluster_avgamt)))
plt.ylim(0, 400)
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

cluster_colors = {
    0 : 'red',
    1 : 'blue',
    2 : 'orange',
    3 : 'green',
    4 : 'darkgrey'
}

# Summing up the number of round trip flights per cluster
round_trip_flight = final_dataframe.groupby('Cluster')['round_trip'].sum()

plt.figure(figsize=(10, 6))

for cluster in range(len(round_trip_flight)):
    plt.bar(cluster, round_trip_flight[cluster], color=cluster_colors[cluster])
    # Add the number of round trip flights as text on top of the bar
    plt.text(cluster, round_trip_flight[cluster] + 10,  # Adjust "+ 10" for spacing
             str(round_trip_flight[cluster]), ha='center', va='bottom', fontsize=10, color='black')

plt.title('Number of Round Trip Flights per Cluster')
plt.xlabel('Cluster')
plt.ylabel('Number of People Taking Round Trip Flights')
plt.xticks(ticks=range(len(round_trip_flight)))
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %%
cluster_colors = {
    0 : 'red',
    1 : 'blue',
    2 : 'orange',
    3 : 'green',
    4 : 'darkgrey'
}


# Ensure the age_group column is a categorical type with the correct order
age_group_order = ['0-17', '18-24', '25-34', '35-54', '55+']
cluster_0_data = final_dataframe[final_dataframe['Cluster'] == 0]

# Ensure the age_group column is treated as categorical with the correct order
cluster_0_data['age_group'] = pd.Categorical(cluster_0_data['age_group'], categories=age_group_order, ordered=True)

# Counting the occurrences of each age group
age_group_counts = cluster_0_data['age_group'].value_counts().reindex(age_group_order)

plt.figure(figsize=(10, 6))

# Creating a bar plot instead of a histogram to ensure correct ordering
plt.bar(age_group_counts.index, age_group_counts.values, color=cluster_colors[0], edgecolor='black')

plt.title('Bar graph of Age Groups for Cluster 0')
plt.xlabel('Age Group')
plt.ylabel('Frequency')
plt.grid(axis='y')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-14-466e464b5125>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cluster_0_data['age_group'] = pd.Categorical(cluster_0_data['age_group'], categories=age_group_order, ordered=True)

# %%
import matplotlib.pyplot as plt

# Filtering the dataframe for cluster 0
cluster_0_data = final_dataframe[final_dataframe['Cluster'] == 0]

# Extracting the relevant columns
days_pre_booked_cluster_0 = cluster_0_data['days_pre_booked']

plt.figure(figsize=(10, 6))

# Creating the histogram and capturing the returned values
n, bins, patches = plt.hist(days_pre_booked_cluster_0, bins=15, color=cluster_colors[0], edgecolor='black')

# Adding labels on top of each bar with the corresponding X-axis (bin midpoint) value
for i in range(len(patches)):
    # Calculate the midpoint of the bin
    bin_midpoint = (bins[i] + bins[i+1]) / 2
    plt.text(bin_midpoint, n[i], str(int(bin_midpoint)),
             ha='center', va='bottom', fontsize=10)

plt.title('Histogram of Days Pre-booked for Cluster 0')
plt.xlabel('Days Pre-booked')
plt.ylabel('Frequency')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.tight_layout()
plt.show()

# %%
import pandas as pd

# Filtering the dataframe for cluster 0
cluster_0_data = final_dataframe[final_dataframe['Cluster'] == 0]

# Counting the occurrences of each group size
group_size_counts = cluster_0_data['group_size'].value_counts().sort_index()

plt.figure(figsize=(10, 6))

# Creating a bar plot for group size in Cluster 0
plt.bar(group_size_counts.index.astype(str), group_size_counts.values, color=cluster_colors[0], edgecolor='black')

plt.title('Bar graph of Group Size for Cluster 0')
plt.xlabel('Group Size')
plt.ylabel('Frequency')
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Filtering the dataframe for cluster 0
cluster_0_data = final_dataframe[final_dataframe['Cluster'] == 0]

# Extracting the relevant columns
booking_channel_cluster_0 = cluster_0_data['BookingChannel']

plt.figure(figsize=(10, 6))

# Counting the occurrences of each booking channel
booking_channel_counts = booking_channel_cluster_0.value_counts().sort_index()

# Creating the bar plot for Booking Channel
plt.bar(booking_channel_counts.index, booking_channel_counts.values, color=cluster_colors[0], edgecolor='black')

# Adding labels on top of each bar with the count value
for i, value in enumerate(booking_channel_counts.values):
    plt.text(i, value, str(value), ha='center', va='bottom', fontsize=10)

plt.title('Histogram of Booking Channel for Cluster 0')
plt.xlabel('Booking Channel')
plt.ylabel('Frequency')
plt.grid(True, axis='y', linestyle='--', linewidth=0.5)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Filtering the dataframe for cluster 0
cluster_0_data = final_dataframe[final_dataframe['Cluster'] == 0]

# Extracting the relevant columns
booking_channel_cluster_0 = cluster_0_data['BookingChannel']

# Counting the occurrences of each booking channel
booking_channel_counts = booking_channel_cluster_0.value_counts().sort_index()

plt.figure(figsize=(8, 8))

# Creating the pie chart for Booking Channel
# Use a list comprehension to extract colors from cluster_colors based on index
plt.pie(booking_channel_counts.values, labels=booking_channel_counts.index, autopct='%1.1f%%', startangle=140, colors=[cluster_colors[i] for i in range(len(booking_channel_counts))], wedgeprops={'edgecolor': 'black'})

plt.title('Pie Chart of Booking Channel for Cluster 0')
plt.tight_layout()
plt.show()

# %%
import pandas as pd

# Ensure the age_group column is a categorical type with the correct order
age_group_order = ['0-17', '18-24', '25-34', '35-54', '55+']
cluster_1_data = final_dataframe[final_dataframe['Cluster'] == 1]

# Ensure the age_group column is treated as categorical with the correct order
cluster_1_data['age_group'] = pd.Categorical(cluster_1_data['age_group'], categories=age_group_order, ordered=True)

# Counting the occurrences of each age group
age_group_counts = cluster_1_data['age_group'].value_counts().reindex(age_group_order)

plt.figure(figsize=(10, 6))

# Creating a bar plot instead of a histogram to ensure correct ordering
plt.bar(age_group_counts.index, age_group_counts.values, color=cluster_colors[1], edgecolor='black')

plt.title('Bar graph of Age Groups for Cluster 1')
plt.xlabel('Age Group')
plt.ylabel('Frequency')
plt.grid(axis='y')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-25-040796f684af>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cluster_1_data['age_group'] = pd.Categorical(cluster_1_data['age_group'], categories=age_group_order, ordered=True)

# %%
import matplotlib.pyplot as plt

# Filtering the dataframe for cluster 1
cluster_1_data = final_dataframe[final_dataframe['Cluster'] == 1]

# Extracting the relevant columns
days_pre_booked_cluster_1 = cluster_1_data['days_pre_booked']

plt.figure(figsize=(10, 6))

# Creating the histogram and capturing the returned values
n, bins, patches = plt.hist(days_pre_booked_cluster_1, bins=15, color=cluster_colors[1], edgecolor='black')

# Adding labels on top of each bar with the corresponding X-axis (bin midpoint) value
for i in range(len(patches)):
    # Calculate the midpoint of the bin
    bin_midpoint = (bins[i] + bins[i+1]) / 2
    plt.text(bin_midpoint, n[i], str(int(bin_midpoint)),
             ha='center', va='bottom', fontsize=10)

plt.title('Histogram of Days Pre-booked for Cluster 1')
plt.xlabel('Days Pre-booked')
plt.ylabel('Frequency')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Filtering the dataframe for cluster 1
cluster_1_data = final_dataframe[final_dataframe['Cluster'] == 1]

# Extracting relevant columns
group_sizes = cluster_1_data['group_size']
total_spend = cluster_1_data['BaseFareAmt']  # Assuming 'total_spend' is a column in your data

plt.figure(figsize=(10, 6))

# Creating a scatter plot
plt.scatter(group_sizes, total_spend, color='blue', edgecolor='black')

plt.title('Scatter Plot of Group Size vs. Total Spend for Cluster 1')
plt.xlabel('Group Size')
plt.ylabel('Total Spend')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import pandas as pd

# Filtering the dataframe for cluster 1
cluster_1_data = final_dataframe[final_dataframe['Cluster'] == 1]

# Counting the occurrences of each group size
group_size_counts = cluster_1_data['group_size'].value_counts().sort_index()

plt.figure(figsize=(10, 6))

# Creating a bar plot for group size in Cluster 1
plt.bar(group_size_counts.index.astype(str), group_size_counts.values, color=cluster_colors[1], edgecolor='black')

plt.title('Bar graph of Group Size for Cluster 1')
plt.xlabel('Group Size')
plt.ylabel('Frequency')
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Filtering the dataframe for cluster 1
cluster_1_data = final_dataframe[final_dataframe['Cluster'] == 1]

# Extracting the relevant columns
booking_channel_cluster_1 = cluster_1_data['BookingChannel']

plt.figure(figsize=(10, 6))

# Counting the occurrences of each booking channel
booking_channel_counts = booking_channel_cluster_1.value_counts().sort_index()

# Creating the bar plot for Booking Channel
plt.bar(booking_channel_counts.index, booking_channel_counts.values, color=cluster_colors[1], edgecolor='black')

# Adding labels on top of each bar with the count value
for i, value in enumerate(booking_channel_counts.values):
    plt.text(i, value, str(value), ha='center', va='bottom', fontsize=10)

plt.title('Bar graph of Booking Channel for Cluster 1')
plt.xlabel('Booking Channel')
plt.ylabel('Frequency')
plt.grid(True, axis='y', linestyle='--', linewidth=0.5)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Filtering the dataframe for cluster 1
cluster_1_data = final_dataframe[final_dataframe['Cluster'] == 1]

# Extracting the relevant columns
days_pre_booked_cluster_1 = cluster_1_data['days_pre_booked']
base_fare_amt_cluster_1 = cluster_1_data['BaseFareAmt']

plt.figure(figsize=(10, 6))

# Creating the scatter plot
plt.scatter(days_pre_booked_cluster_1, base_fare_amt_cluster_1, color=cluster_colors[1], edgecolor='black')

plt.title('Scatter Plot of Days Pre-booked vs. Base Fare Amount for Cluster 1')
plt.xlabel('Days Pre-booked')
plt.ylabel('Base Fare Amount')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Filtering the dataframe for cluster 1
cluster_1_data = final_dataframe[final_dataframe['Cluster'] == 1]

# Extracting the relevant columns
booking_channel_cluster_1 = cluster_1_data['BookingChannel']

# Counting the occurrences of each booking channel
booking_channel_counts = booking_channel_cluster_1.value_counts().sort_index()

plt.figure(figsize=(8, 8))

# Define cluster_colors if it doesn't exist or has an invalid value
# Ensure it has enough colors for each slice of the pie chart
cluster_colors = ['red', 'green', 'blue', 'orange']  # Example colors

# Creating the pie chart for Booking Channel
plt.pie(booking_channel_counts.values, labels=booking_channel_counts.index,
        autopct=lambda p: '{:.0f}'.format(p * sum(booking_channel_counts.values) / 100),
        startangle=140, colors=cluster_colors[:len(booking_channel_counts)],
        wedgeprops={'edgecolor': 'black'})

plt.title('Pie Chart of Booking Channel for Cluster 1')
plt.tight_layout()
plt.show()

# %%
import pandas as pd

# Ensure the age_group column is a categorical type with the correct order
age_group_order = ['0-17', '18-24', '25-34', '35-54', '55+']
cluster_2_data = final_dataframe[final_dataframe['Cluster'] == 2]

# Ensure the age_group column is treated as categorical with the correct order
cluster_2_data['age_group'] = pd.Categorical(cluster_2_data['age_group'], categories=age_group_order, ordered=True)

# Counting the occurrences of each age group
age_group_counts = cluster_2_data['age_group'].value_counts().reindex(age_group_order)

plt.figure(figsize=(10, 6))

# Creating a bar plot instead of a histogram to ensure correct ordering
plt.bar(age_group_counts.index, age_group_counts.values, color=cluster_colors[2], edgecolor='black')

plt.title('Bar graph of Age Groups for Cluster 2')
plt.xlabel('Age Group')
plt.ylabel('Frequency')
plt.grid(axis='y')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-22-c0ba079d9688>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cluster_2_data['age_group'] = pd.Categorical(cluster_2_data['age_group'], categories=age_group_order, ordered=True)

# %%
import matplotlib.pyplot as plt

# Filtering the dataframe for cluster 2
cluster_2_data = final_dataframe[final_dataframe['Cluster'] == 2]

# Extracting the relevant columns
days_pre_booked_cluster_2 = cluster_2_data['days_pre_booked']

plt.figure(figsize=(10, 6))

# Creating the histogram and capturing the returned values
n, bins, patches = plt.hist(days_pre_booked_cluster_2, bins=15, color=cluster_colors[2], edgecolor='black')

# Adding labels on top of each bar with the corresponding X-axis (bin midpoint) value
for i in range(len(patches)):
    # Calculate the midpoint of the bin
    bin_midpoint = (bins[i] + bins[i+1]) / 2
    plt.text(bin_midpoint, n[i], str(int(bin_midpoint)),
             ha='center', va='bottom', fontsize=10)

plt.title('Histogram of Days Pre-booked for Cluster 2')
plt.xlabel('Days Pre-booked')
plt.ylabel('Frequency')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming 'age_group', 'seasonality', and 'Cluster' are columns in your dataframe.
# Adjust column names according to your actual dataframe.

# Filtering the dataframe for Cluster 2
cluster_2_data = final_dataframe[final_dataframe['Cluster'] == 2]

plt.figure(figsize=(10, 7))

# Define cluster_colors with sufficient elements if it doesn't exist
cluster_colors = ['red', 'green', 'blue', 'orange']  # Example colors

# Plot scatter plot for Cluster 2
plt.scatter(cluster_2_data['Age'], cluster_2_data['seasonality'], color=cluster_colors[2], label='Cluster 2', alpha=0.6)

plt.title("Age Group vs Seasonality for Cluster 2")
plt.xlabel("Age Group")
plt.ylabel("Seasonality")
plt.legend(title="Cluster", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt

# Define the colors for each cluster
cluster_colors = {
     0 : 'red',
     1 : 'blue',
     2 : 'orange',
     3 : 'green',
     4 : 'darkgrey'
}

# Group the data by 'Cluster' and 'TrvldClassOfService' and count occurrences
cluster_travel_size  = final_dataframe.groupby(['Cluster', 'TrvldClassOfService'])['TrvldClassOfService'].count()

# Pivot the data to get counts for each travel class per cluster
pivot_data = cluster_travel_size.unstack(level=1).fillna(0)

# Extract data for Cluster 2
cluster_2_data = pivot_data.loc[2]

# Plot a pie chart for Cluster 2 with counts instead of percentages
plt.figure(figsize=(8,8))
plt.pie(cluster_2_data, labels=cluster_2_data.index, colors=cluster_colors.values(),
        autopct=lambda p: f'{int(round(p*sum(cluster_2_data)/100))}', startangle=140)
plt.title("Travel Class of Service Distribution for Cluster 2")
plt.show()

# %%
import pandas as pd

# Filtering the dataframe for cluster 2
cluster_2_data = final_dataframe[final_dataframe['Cluster'] == 2]

# Counting the occurrences of each group size
group_size_counts = cluster_2_data['group_size'].value_counts().sort_index()

plt.figure(figsize=(10, 6))

# Creating a bar plot for group size in Cluster 2
plt.bar(group_size_counts.index.astype(str), group_size_counts.values, color=cluster_colors[2], edgecolor='black')

plt.title('Bar graph of Group Size for Cluster 2')
plt.xlabel('Group Size')
plt.ylabel('Frequency')
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Filtering the dataframe for cluster 2
cluster_2_data = final_dataframe[final_dataframe['Cluster'] == 2]

# Extracting the relevant columns
booking_channel_cluster_2 = cluster_2_data['BookingChannel']

plt.figure(figsize=(10, 6))

# Counting the occurrences of each booking channel
booking_channel_counts = booking_channel_cluster_2.value_counts().sort_index()

# Creating the bar plot for Booking Channel
plt.bar(booking_channel_counts.index, booking_channel_counts.values, color=cluster_colors[2], edgecolor='black')

# Adding labels on top of each bar with the count value
for i, value in enumerate(booking_channel_counts.values):
    plt.text(i, value, str(value), ha='center', va='bottom', fontsize=10)

plt.title('Bar graph of Booking Channel for Cluster 2')
plt.xlabel('Booking Channel')
plt.ylabel('Frequency')
plt.grid(True, axis='y', linestyle='--', linewidth=0.5)
plt.tight_layout()
plt.show()

# %%
import pandas as pd

# Ensure the age_group column is a categorical type with the correct order
age_group_order = ['0-17', '18-24', '25-34', '35-54', '55+']
cluster_3_data = final_dataframe[final_dataframe['Cluster'] == 3]

# Ensure the age_group column is treated as categorical with the correct order
cluster_3_data['age_group'] = pd.Categorical(cluster_3_data['age_group'], categories=age_group_order, ordered=True)

# Counting the occurrences of each age group
age_group_counts = cluster_3_data['age_group'].value_counts().reindex(age_group_order)

plt.figure(figsize=(10, 6))

# Creating a bar plot instead of a histogram to ensure correct ordering
plt.bar(age_group_counts.index, age_group_counts.values, color=cluster_colors[3], edgecolor='black')

plt.title('Bar graph of Age Groups for Cluster 3')
plt.xlabel('Age Group')
plt.ylabel('Frequency')
plt.grid(axis='y')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-19-61dbd719678f>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cluster_3_data['age_group'] = pd.Categorical(cluster_3_data['age_group'], categories=age_group_order, ordered=True)

# %%
import matplotlib.pyplot as plt

# Filtering the dataframe for cluster 3
cluster_3_data = final_dataframe[final_dataframe['Cluster'] == 3]

# Extracting the relevant columns
days_pre_booked_cluster_3 = cluster_3_data['days_pre_booked']

plt.figure(figsize=(10, 6))

# Creating the histogram and capturing the returned values
n, bins, patches = plt.hist(days_pre_booked_cluster_3, bins=15, color=cluster_colors[3], edgecolor='black')

# Adding labels on top of each bar with the corresponding X-axis (bin midpoint) value
for i in range(len(patches)):
    # Calculate the midpoint of the bin
    bin_midpoint = (bins[i] + bins[i+1]) / 2
    plt.text(bin_midpoint, n[i], str(int(bin_midpoint)),
             ha='center', va='bottom', fontsize=10)

plt.title('Histogram of Days Pre-booked for Cluster 3')
plt.xlabel('Days Pre-booked')
plt.ylabel('Frequency')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.tight_layout()
plt.show()

# %%
import pandas as pd

# Filtering the dataframe for cluster 3
cluster_3_data = final_dataframe[final_dataframe['Cluster'] == 3]

# Counting the occurrences of each group size
group_size_counts = cluster_3_data['group_size'].value_counts().sort_index()

plt.figure(figsize=(10, 6))

# Creating a bar plot for group size
plt.bar(group_size_counts.index.astype(str), group_size_counts.values, color=cluster_colors[3], edgecolor='black')

plt.title('Bar graph of Group Size for Cluster 3')
plt.xlabel('Group Size')
plt.ylabel('Frequency')
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Filtering the dataframe for cluster 3
cluster_3_data = final_dataframe[final_dataframe['Cluster'] == 3]

# Extracting the relevant columns
booking_channel_cluster_3 = cluster_3_data['BookingChannel']

plt.figure(figsize=(10, 6))

# Counting the occurrences of each booking channel
booking_channel_counts = booking_channel_cluster_3.value_counts().sort_index()

# Creating the bar plot for Booking Channel
plt.bar(booking_channel_counts.index, booking_channel_counts.values, color=cluster_colors[3], edgecolor='black')

# Adding labels on top of each bar with the count value
for i, value in enumerate(booking_channel_counts.values):
    plt.text(i, value, str(value), ha='center', va='bottom', fontsize=10)

plt.title('Bar graph of Booking Channel for Cluster 3')
plt.xlabel('Booking Channel')
plt.ylabel('Frequency')
plt.grid(True, axis='y', linestyle='--', linewidth=0.5)
plt.tight_layout()
plt.show()

# %%
import pandas as pd

# Filtering the dataframe for cluster 4
cluster_4_data = final_dataframe[final_dataframe['Cluster'] == 4]

# Counting the occurrences of each group size
group_size_counts = cluster_4_data['group_size'].value_counts().sort_index()

plt.figure(figsize=(10, 6))

# Creating a bar plot for group size in Cluster 4
plt.bar(group_size_counts.index.astype(str), group_size_counts.values, color=cluster_colors[4], edgecolor='black')

plt.title('Bar graph of Group Size for Cluster 4')
plt.xlabel('Group Size')
plt.ylabel('Frequency')
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %%
import pandas as pd

# Ensure the age_group column is a categorical type with the correct order
age_group_order = ['0-17', '18-24', '25-34', '35-54', '55+']
cluster_4_data = final_dataframe[final_dataframe['Cluster'] == 4]

# Ensure the age_group column is treated as categorical with the correct order
cluster_4_data['age_group'] = pd.Categorical(cluster_4_data['age_group'], categories=age_group_order, ordered=True)

# Counting the occurrences of each age group
age_group_counts = cluster_4_data['age_group'].value_counts().reindex(age_group_order)

plt.figure(figsize=(10, 6))

# Creating a bar plot instead of a histogram to ensure correct ordering
plt.bar(age_group_counts.index, age_group_counts.values, color=cluster_colors[4], edgecolor='black')

plt.title('Bar graph of Age Groups for Cluster 4')
plt.xlabel('Age Group')
plt.ylabel('Frequency')
plt.grid(axis='y')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-15-11d946ff8b9d>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cluster_4_data['age_group'] = pd.Categorical(cluster_4_data['age_group'], categories=age_group_order, ordered=True)

# %%
import matplotlib.pyplot as plt

# Filtering the dataframe for cluster 4
cluster_4_data = final_dataframe[final_dataframe['Cluster'] == 4]

# Extracting the relevant columns
days_pre_booked_cluster_4 = cluster_4_data['days_pre_booked']

plt.figure(figsize=(10, 6))

# Creating the histogram and capturing the returned values
n, bins, patches = plt.hist(days_pre_booked_cluster_4, bins=15, color=cluster_colors[4], edgecolor='black')

# Adding labels on top of each bar with the corresponding X-axis (bin midpoint) value
for i in range(len(patches)):
    # Calculate the midpoint of the bin
    bin_midpoint = (bins[i] + bins[i+1]) / 2
    plt.text(bin_midpoint, n[i], str(int(bin_midpoint)),
             ha='center', va='bottom', fontsize=10)

plt.title('Histogram of Days Pre-booked for Cluster 4')
plt.xlabel('Days Pre-booked')
plt.ylabel('Frequency')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Filtering the dataframe for cluster 4
cluster_4_data = final_dataframe[final_dataframe['Cluster'] == 4]

# Extracting the relevant columns
booking_channel_cluster_4 = cluster_4_data['BookingChannel']

plt.figure(figsize=(10, 6))

# Counting the occurrences of each booking channel
booking_channel_counts = booking_channel_cluster_4.value_counts().sort_index()

# Creating the bar plot for Booking Channel
plt.bar(booking_channel_counts.index, booking_channel_counts.values, color=cluster_colors[4], edgecolor='black')

# Adding labels on top of each bar with the count value
for i, value in enumerate(booking_channel_counts.values):
    plt.text(i, value, str(value), ha='center', va='bottom', fontsize=10)

plt.title('Bar graph of Booking Channel for Cluster 4')
plt.xlabel('Booking Channel')
plt.ylabel('Frequency')
plt.grid(True, axis='y', linestyle='--', linewidth=0.5)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Filtering the dataframe for cluster 4
cluster_4_data = final_dataframe[final_dataframe['Cluster'] == 4]

# Extracting the relevant columns
ufly_member_status_cluster_4 = cluster_4_data['UflyMemberStatus']

plt.figure(figsize=(10, 6))

# Counting the occurrences of each Ufly Member Status
ufly_member_status_counts = ufly_member_status_cluster_4.value_counts().sort_index()

# Creating the bar plot for Ufly Member Status
# Define cluster_colors
cluster_colors = ['grey'] # Example list of colors - adjust as needed.

plt.bar(ufly_member_status_counts.index, ufly_member_status_counts.values, color='grey', edgecolor='black')

# Adding labels on top of each bar with the count value
for i, value in enumerate(ufly_member_status_counts.values):
    plt.text(i, value, str(value), ha='center', va='bottom', fontsize=10)

plt.title('Bar graph of Ufly Member Status for Cluster 4')
plt.xlabel('Ufly Member Status')
plt.ylabel('Frequency')
plt.grid(True, axis='y', linestyle='--', linewidth=0.5)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Filtering the dataframe for cluster 4
cluster_4_data = final_dataframe[final_dataframe['Cluster'] == 4]

# Create a crosstab to get counts of each combination of UflyMemberStatus and TrvldClassOfService
crosstab_data = pd.crosstab(cluster_4_data['UflyMemberStatus'], cluster_4_data['TrvldClassOfService'])

plt.figure(figsize=(10, 6))

# Creating the stacked bar chart
crosstab_data.plot(kind='bar', stacked=True, color=['red', 'blue', 'orange', 'green', 'darkgrey'], edgecolor='black', figsize=(10, 6))

plt.title('Stacked Bar Chart of Ufly Member Status and Travel Class of Service for Cluster 4')
plt.xlabel('Ufly Member Status')
plt.ylabel('Count')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Filtering the dataframe for cluster 4
cluster_4_data = final_dataframe[final_dataframe['Cluster'] == 4]

# Create a crosstab to get counts of each combination of UflyMemberStatus and TrvldClassOfService
crosstab_data = pd.crosstab(cluster_4_data['UflyMemberStatus'], cluster_4_data['TrvldClassOfService'])

# Convert counts to percentages
crosstab_percentage = crosstab_data.div(crosstab_data.sum(axis=1), axis=0) * 100

plt.figure(figsize=(10, 6))

# Creating the stacked bar chart with percentages
crosstab_percentage.plot(kind='bar', stacked=True, color=['red', 'blue', 'orange', 'green', 'darkgrey'], edgecolor='black', figsize=(10, 6))

plt.title('Stacked Bar Chart of Ufly Member Status vs. Travel Class of Service for Cluster 4 in Percentage')
plt.xlabel('Ufly Member Status')
plt.ylabel('Percentage')
plt.legend(title="Travel Class of Service", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Filtering the dataframe for cluster 4
cluster_4_data = final_dataframe[final_dataframe['Cluster'] == 4]

# Extracting the relevant columns
days_pre_booked_cluster_4 = cluster_4_data['days_pre_booked']
base_fare_amt_cluster_4 = cluster_4_data['BaseFareAmt']

plt.figure(figsize=(10, 6))

# Creating the scatter plot
plt.scatter(days_pre_booked_cluster_4, base_fare_amt_cluster_4, color=cluster_colors[4], edgecolor='black')

plt.title('Scatter Plot of Days Pre-booked vs. Base Fare Amount for Cluster 4')
plt.xlabel('Days Pre-booked')
plt.ylabel('Base Fare Amount')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Filtering the dataframe for cluster 4
cluster_4_data = final_dataframe[final_dataframe['Cluster'] == 4]

# Extracting the relevant columns
Cluster_4_age = cluster_4_data['Age']
Cluster_4_Travel_Class = cluster_4_data['TrvldClassOfService']

plt.figure(figsize=(10, 6))

# Creating the scatter plot
plt.scatter(Cluster_4_Travel_Class, Cluster_4_age, color=cluster_colors[4], edgecolor='black')

plt.title('Scatter Plot of Age vs Travel Class for Cluster 4')
plt.xlabel('Travel Class')
plt.ylabel('Age')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

monthly_purchases = final_dataframe.groupby(['Cluster', 'seasonality'])['seasonality'].count()
pivot_data = monthly_purchases.unstack(level=1).fillna(0)
pivot_data_percentage = pivot_data.div(pivot_data.sum(axis=1), axis=0) * 100
plt.figure(figsize=(12, 8))
pivot_data.plot(kind='bar', stacked=True, colormap='tab20', figsize=(12, 8))
plt.title("Number of Customers by Cluster and Seasonality")
plt.xlabel("Cluster")
plt.ylabel("Number of Customers")
plt.legend(title="Seasonality", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# percentages
plt.figure(figsize=(12, 8))
pivot_data_percentage.plot(kind='bar', stacked=True, colormap='tab20', figsize=(12, 8))
plt.title("Percentage of Customers by Cluster and Seasonality")
plt.xlabel("Cluster")
plt.ylabel("Percentage (%)")
plt.legend(title="Seasonality", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
cluster_memberstatus  = final_dataframe.groupby(['Cluster', 'UflyMemberStatus'])['UflyMemberStatus'].count()

pivot_data = cluster_memberstatus.unstack(level=1).fillna(0)

pivot_data.plot(kind= 'bar', stacked=True, figsize=(10,7))
plt.title("Member status of Each Cluster")
plt.xlabel("Cluster")
plt.ylabel('Number of People')
plt.legend(title="Member Status", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
cluster_colors = {
     0 : 'red',
    1 : 'blue',
    2 : 'orange',
    3 : 'green',
    4 : 'darkgrey'

}



cluster_travel_size  = final_dataframe.groupby(['Cluster', 'TrvldClassOfService'])['TrvldClassOfService'].count()

pivot_data = cluster_travel_size.unstack(level=1).fillna(0)

pivot_data.plot(kind= 'bar', stacked=True, figsize=(10,7))
plt.title("Travel Class of Service")
plt.xlabel("Cluster")
plt.ylabel('Travel Class')
plt.legend(title="Travel Class", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
monthly_purchases = final_dataframe.groupby(['Cluster', 'seasonality'])['seasonality'].count()

pivot_data = monthly_purchases.unstack(level=1).fillna(0)

pivot_data.plot(kind= 'bar', stacked=True, figsize=(10,7))
plt.title("Number of clusters by seasonality")
plt.xlabel("Cluster")
plt.ylabel("Number of customers")
plt.legend(title="Seasonality", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Define the colors for each cluster
cluster_colors = {
     0 : 'red',
     1 : 'blue',
     2 : 'orange',
     3 : 'green',
     4 : 'darkgrey'
}

# Group the data by 'Cluster' and 'TrvldClassOfService' and count occurrences
cluster_travel_size  = final_dataframe.groupby(['Cluster', 'TrvldClassOfService'])['TrvldClassOfService'].count()

# Pivot the data to get counts for each travel class per cluster
pivot_data = cluster_travel_size.unstack(level=1).fillna(0)

# Extract data for Cluster 4
cluster_4_data = pivot_data.loc[4]

# Plot a pie chart for Cluster 4 with counts instead of percentages
plt.figure(figsize=(8,8))
plt.pie(cluster_4_data, labels=cluster_4_data.index, colors=cluster_colors.values(),
        autopct=lambda p: f'{int(round(p*sum(cluster_4_data)/100))}', startangle=140)
plt.title("Travel Class of Service Distribution for Cluster 4")
plt.show()

# %% [markdown]
# ```

# %%
import matplotlib.pyplot as plt

# Define age group order and clusters
age_group_order = ['0-17', '18-24', '25-34', '35-54', '55+']
clusters = [0, 1, 2, 3, 4]  # Cluster labels

# Get the data from the final dataframe (already grouped by 'Cluster' and 'age_group')
cluster_age_group_counts = final_dataframe.groupby(['Cluster', 'age_group'])['age_group'].count().unstack().fillna(0)

# Create a bubble chart
plt.figure(figsize=(10, 7))

# Iterate over clusters to plot bubbles
for cluster in clusters:
    for age_group in age_group_order:
        # Get the count (bubble size) for the current cluster and age group
        count = cluster_age_group_counts.loc[cluster, age_group]

        # Plot the bubble
        plt.scatter(cluster, age_group_order.index(age_group),
                    s=count * 10,  # Adjust bubble size
                    color=cluster_colors[cluster], alpha=0.6, label=f'Cluster {cluster}' if age_group == '0-17' else "")

# Set the x and y labels
plt.xlabel('Cluster')
plt.ylabel('Age Group')
plt.title('Cluster Age Groups')

# Customize the y-axis to show age group labels
plt.yticks(range(len(age_group_order)), age_group_order)

# Display the plot
plt.tight_layout()
plt.show()
